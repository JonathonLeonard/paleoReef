# %%
import glob
from gplately import pygplates
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pygmt
import scipy
import shutil
import sys
import xarray as xr

# %%
ages = list(np.arange(0,260,10)) # Ages that we simulated temperature for
var = 'puma_temperature_surface_air' #variable name to get aves from (probably air temp)

colours = ['plum','lightblue','salmon','yellowgreen','blue','red','green','cyan','orange','pink']

# Scotese (2021) paleotemperature data (from publication's supplementary data)
scoteseVar = pd.ExcelFile('/Users/jono/Documents/Databases/scotese2021_paleotemps/Part 4. Phanerozoic_Paleotemperature_Summaryv4.xlsx')
scoteseVar = pd.read_excel(scoteseVar, '1my version') # Read the specific sheet 


# Get the paths to the climate models
model_path = '/Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign'
co2s=['100','200','280','560','1120','2240','4480','fosterCO2']
models=[]
for co2 in co2s:
    model = os.path.join(model_path,f'2024-07-23_earthbyte_paleo_PaleomagRef_{co2}')
    # model = os.path.join(model_path,f'2024-10-08_scotese_paleo_{co2}ppm_shallowSea_{co2}')

    models.append(model)

# %%
# Filter Scotese data for simulated ages and create a dataframe
df = scoteseVar[scoteseVar['Age'].isin(ages)][['Age', 'GAT']].set_index('Age').rename(columns={'GAT': 'Scotese'})

# %%
# Add the GMST for each model run
for i in range(len(models)):
    model = models[i]
    co2 = co2s[i]
    for age in ages:
        plasimGrid = f'{model}/{str(age)}Ma_nc_outputs/3000-12-30_plasim.nc'

        if not os.path.exists(plasimGrid):
            print(f'{plasimGrid} does not exist, continuing but this may not work')
            continue

        info = pygmt.grdinfo(grid=f'{plasimGrid}?{var}', per_column=True, force_scan='2')

        mean = round(float(info.split()[10]), 4)

        df.at[age,co2] = mean

df
# Out:
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/0Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/40Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/60Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/70Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/80Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/120Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/130Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/140Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/150Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/160Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/170Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/180Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/190Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/200Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/210Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/220Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/230Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/0Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/60Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/70Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/80Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/90Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/120Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/50Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/90Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/100Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_100/110Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/40Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/50Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/100Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/110Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/130Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/140Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/150Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/160Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/170Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/180Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/190Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/200Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/210Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/220Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/230Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_200/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/0Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/40Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/50Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/60Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/70Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/80Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/90Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/120Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/130Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/140Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/150Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/160Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/170Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/180Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/190Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/200Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/210Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/220Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/230Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/0Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/40Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/50Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/60Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/70Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/80Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/90Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/100Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/100Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_280/110Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/110Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/120Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/130Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/140Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/150Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/160Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/170Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/180Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/190Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/200Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/210Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/220Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/230Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_560/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_1120/0Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_1120/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_1120/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_1120/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_1120/40Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# ...
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_4480/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_4480/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/10Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/20Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/30Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/40Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/50Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/60Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/70Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/80Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/90Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/100Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/110Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/120Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/130Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/140Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/150Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/160Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/170Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/180Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/190Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/200Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/210Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/220Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/230Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/240Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# grdinfo [WARNING]: The step size of coordinate (latitude) in grid /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/250Ma_nc_outputs/3000-12-30_plasim.nc is not constant.
# grdinfo [WARNING]: GMT will use a constant step size of -5.53294; the original ranges from -5.53781 to -5.49181.
# grdinfo [WARNING]: Guessing of registration in conflict between x and y, using gridline
# /Users/jono/OneDrive - The University of Sydney (Staff)/paleoReef/climateModelData_OGnorealign/2024-07-23_earthbyte_paleo_PaleomagRef_fosterCO2/0Ma_nc_outputs/3000-12-30_plasim.nc does not exist, continuing but this may not work
#          Scotese     100      200      280      560     1120     2240  \
# Age
# 0.0    14.500000 -2.8109   7.9752  14.0707  18.7654  21.8008  24.7921
# 10.0   16.251666 -2.9507   9.1215  14.3584  18.4159  21.8886  24.7652
# 20.0   17.326809  0.2997   7.7794  14.8754  18.9492  22.1518  24.9920
# 30.0   17.935121 -0.0851   9.0575  14.3984  19.2638  22.4361  25.1918
# 40.0   21.426648  0.4013      NaN  15.8471  19.5513  22.6139  25.5361
# 50.0   25.140929     NaN      NaN  15.7741  19.5523  22.7792  25.5470
# 60.0   22.580030  2.0568  10.2120  14.6047  19.1995  22.3614  25.1869
# 70.0   21.105640  1.8805   9.4609  15.8432  19.7458  22.6663  25.4138
# 80.0   22.041626  1.2157   9.9595  15.2822  19.7595  22.4562  25.3059
# 90.0   27.375668     NaN  11.5566  15.3973  19.7449  22.7755  25.6353
# 100.0  23.312262     NaN      NaN      NaN  19.6826  22.6717  25.6699
# 110.0  21.062254     NaN      NaN      NaN  19.1950  22.2935  25.3282
# 120.0  23.920522 -1.3471  12.1716  15.0085  19.3250  22.4224  25.4788
# 130.0  20.856740 -2.8455  11.5232  15.2354  19.1255  22.2656  25.1114
# 140.0  19.241037 -2.5579  14.1920  15.9425  19.2807  22.3666  25.0502
# 150.0  19.996675 -2.7022  13.4137  15.2933  19.2143  22.4825  25.0572
# 160.0  19.781524 -1.6676  13.3092  15.1897  18.8430  22.1938  24.8218
# 170.0  21.818304 -1.8983  12.0348  14.5909  18.1886  21.8588  24.7792
# 180.0  23.085664  4.0152  12.8724  15.0285  18.9288  22.2945  24.8477
# 190.0  21.257805  4.6316  12.2159  14.8889  19.1902  22.5483  25.0398
# 200.0  24.146985  4.5003  10.7132  13.9311  19.0928  22.4139  25.0333
# 210.0  25.004098  2.9625  11.1787  13.5829  18.1421  21.9922  25.1746
# 220.0  23.509197  3.1882  12.3897  14.5932  18.9072  22.5067  25.0241
# 230.0  24.712603  2.4633  11.0256  13.4258  19.0128  22.3851  24.9072
# 240.0  25.568215  3.0159  13.5324  15.5090  18.7788  22.4577  24.9820
# 250.0  32.688763  1.5264  13.0805  15.3421  18.8047  22.3955  24.7993
#
#           4480  fosterCO2
# Age
# 0.0    28.0077        NaN
# 10.0   28.1752    15.0808
# 20.0   28.4436    16.1152
# 30.0   28.6130    20.4451
# 40.0   29.0732    21.1146
# 50.0   29.1717    21.3950
# 60.0   28.8909    16.6577
# 70.0   29.1838    16.5712
# 80.0   29.0941    20.5903
# 90.0   30.0713    18.1666
# 100.0  32.0817    21.5827
# 110.0  31.7249    22.1753
# 120.0  31.3993    22.1301
# 130.0  30.8151    21.5285
# 140.0  28.8896    21.5970
# 150.0  28.6184    20.4834
# 160.0  28.6578    20.7955
# 170.0  28.4274    21.6126
# 180.0  27.6582    21.4053
# 190.0  28.3473    22.4836
# 200.0  28.3613    23.9804
# 210.0  28.1283    22.2245
# 220.0  28.1296    23.7918
# 230.0  27.8239    24.3293
# 240.0  27.9214    18.5185
# 250.0  27.5698    20.8467

# %%
co2='fosterCO2'
df[co2]
fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x=df.index,y=df[co2], marker='*', facecolors=colours[i], edgecolors='black', linewidths=1.25, s=250,  label=f'{co2} ppm')

# %%
outdir = 'co2_GMST'
if os.path.exists(outdir):
    shutil.rmtree(outdir)
os.makedirs(outdir)
i=0
for co2 in co2s:
    print(co2)
    fig, ax = plt.subplots(figsize=(12,8))

    # Set Y-axis limits
    ax.set_ylim(0, 45)
    ax.set_xlim(255,-3.2)

    # Add tick marks for the Y-axis
    ax.set_yticks(np.arange(0, 45, 5))
    ax.set_xticks(np.arange(0, 251, 50))

    ax.set_yticks(np.arange(0, 44.5, 1), minor=True)
    ax.set_xticks(np.arange(0, 251, 10), minor=True)

    # Customize grid appearance
    ax.xaxis.remove_overlapping_locs = False
    ax.yaxis.remove_overlapping_locs = False
    try:
        ax.plot(df.index, df['Scotese'], linewidth=1.2, color='purple', linestyle='-', label='Scotese, 2021')
        ax.scatter(x=df.index,y=df[co2], marker='*', facecolors=colours[i], edgecolors='black', linewidths=1.25, s=250,  label=f'{co2} ppm')
    except Exception as e:
       print(e)
       pass
    co2name = co2
    try:
        int(co2)
    except Exception as e:
        print(e)
        co2name = 'fosterCO2'
        
    ax.set_xlabel('Age (Ma)')
    ax.set_ylabel('GMST ($^\circ$C)')

    # Hide the right and top spines
    ax.spines[['right', 'top']].set_visible(False)

    ax.legend(loc='upper right', ncol=2, frameon=False)    
    plt.savefig(f'{outdir}/{co2name}_gmst_comparison.png')

    i+=1
# Out:
# 100
# 200
# 280
# 560
# 1120
# 2240
# 4480
# fosterCO2
# invalid literal for int() with base 10: 'fosterCO2'

# %%
import imageio
import re
### animation
def animation(directory,name='animation.gif'):
    def extract_starting_integer(s):
        match = re.match(r'(\d+)', s)
        return int(match.group(1)) if match else float('inf')

    images = []
    for im in sorted(os.listdir(directory), key=extract_starting_integer):
        print(im)
        if not im.endswith('png'):
            continue
        images.append(imageio.v2.imread(f'{directory}/{im}'))
    imageio.mimwrite(f'{directory}/{name}',images, duration=500)

animation(outdir)
# Out:
# 100_gmst_comparison.png
# 200_gmst_comparison.png
# 280_gmst_comparison.png
# 560_gmst_comparison.png
# 1120_gmst_comparison.png
# 2240_gmst_comparison.png
# 4480_gmst_comparison.png
# fosterCO2_gmst_comparison.png

# %%
# New dataframe that has how far each simulation is off the Scotese reconstruction
dfDiff = pd.DataFrame()
for co2 in co2s:
    dfDiff[co2] = np.abs(df['Scotese'] - df[co2])

# Create a dictionary that has the closest match model for each age
modelDict = {}
for age in dfDiff.index:
    closestModel = dfDiff.loc[age].idxmin()
    modelDict[age] = closestModel

modelDict # Dictionary of model to use that is closest to Scotese global temps for each age
# Out:
# {0.0: '280',
#  10.0: 'fosterCO2',
#  20.0: 'fosterCO2',
#  30.0: '560',
#  40.0: 'fosterCO2',
#  50.0: '2240',
#  60.0: '1120',
#  70.0: '560',
#  80.0: '1120',
#  90.0: '2240',
#  100.0: '1120',
#  110.0: 'fosterCO2',
#  120.0: '1120',
#  130.0: 'fosterCO2',
#  140.0: '560',
#  150.0: 'fosterCO2',
#  160.0: '560',
#  170.0: '1120',
#  180.0: '1120',
#  190.0: 'fosterCO2',
#  200.0: 'fosterCO2',
#  210.0: '2240',
#  220.0: 'fosterCO2',
#  230.0: '2240',
#  240.0: '2240',
#  250.0: '4480'}

# %%
dfDiff
# Out:
#              100        200        280        560       1120       2240  \
# Age
# 0.0    17.310900   6.524800   0.429300   4.265400   7.300800  10.292100
# 10.0   19.202366   7.130166   1.893266   2.164234   5.636934   8.513534
# 20.0   17.027109   9.547409   2.451409   1.622391   4.824991   7.665191
# 30.0   18.020221   8.877621   3.536721   1.328679   4.500979   7.256679
# 40.0   21.025348        NaN   5.579548   1.875348   1.187252   4.109452
# 50.0         NaN        NaN   9.366829   5.588629   2.361729   0.406071
# 60.0   20.523230  12.368030   7.975330   3.380530   0.218630   2.606870
# 70.0   19.225140  11.644740   5.262440   1.359840   1.560660   4.308160
# 80.0   20.825926  12.082126   6.759426   2.282126   0.414574   3.264274
# 90.0         NaN  15.819068  11.978368   7.630768   4.600168   1.740368
# 100.0        NaN        NaN        NaN   3.629662   0.640562   2.357638
# 110.0        NaN        NaN        NaN   1.867254   1.231246   4.265946
# 120.0  25.267622  11.748922   8.912022   4.595522   1.498122   1.558278
# 130.0  23.702240   9.333540   5.621340   1.731240   1.408860   4.254660
# 140.0  21.798937   5.049037   3.298537   0.039663   3.125563   5.809163
# 150.0  22.698875   6.582975   4.703375   0.782375   2.485825   5.060525
# 160.0  21.449124   6.472324   4.591824   0.938524   2.412276   5.040276
# 170.0  23.716604   9.783504   7.227404   3.629704   0.040496   2.960896
# 180.0  19.070464  10.213264   8.057164   4.156864   0.791164   1.762036
# 190.0  16.626205   9.041905   6.368905   2.067605   1.290495   3.781995
# 200.0  19.646685  13.433785  10.215885   5.054185   1.733085   0.886315
# 210.0  22.041598  13.825398  11.421197   6.861998   3.011897   0.170503
# 220.0  20.320996  11.119497   8.915997   4.601997   1.002497   1.514903
# 230.0  22.249303  13.687003  11.286803   5.699803   2.327503   0.194597
# 240.0  22.552315  12.035815  10.059215   6.789415   3.110515   0.586215
# 250.0  31.162363  19.608263  17.346663  13.884063  10.293263   7.889463
#
#             4480  fosterCO2
# Age
# 0.0    13.507700        NaN
# 10.0   11.923534   1.170866
# 20.0   11.116791   1.211609
# 30.0   10.677879   2.509979
# 40.0    7.646552   0.312048
# 50.0    4.030771   3.745929
# 60.0    6.310870   5.922330
# 70.0    8.078160   4.534440
# 80.0    7.052474   1.451326
# 90.0    2.695632   9.209068
# 100.0   8.769438   1.729562
# 110.0  10.662646   1.113046
# 120.0   7.478778   1.790422
# 130.0   9.958360   0.671760
# 140.0   9.648563   2.355963
# 150.0   8.621725   0.486725
# 160.0   8.876276   1.013976
# 170.0   6.609096   0.205704
# 180.0   4.572536   1.680364
# 190.0   7.089495   1.225795
# 200.0   4.214315   0.166585
# 210.0   3.124202   2.779598
# 220.0   4.620403   0.282603
# 230.0   3.111297   0.383303
# 240.0   2.353185   7.049715
# 250.0   5.118963  11.842063

# %%
colours = ['plum','lightblue','salmon','yellowgreen','blue','red','green','cyan','orange','pink']
colourDict = {}
import matplotlib.lines as mlines
markers = []
labels = []
for i in range(len(co2s)):
    co2 = co2s[i]
    colour = colours[i]
    colourDict[co2] = colour

    # Legend
    marker = mlines.Line2D([], [], color=colour, marker='*', linestyle='None', markersize=15, markeredgewidth=0.5, markeredgecolor='black', label=f'{co2}')
    markers.append(marker)

    if co2 == 'fosterCO2':
        label = 'Foster et al. 2017'
    else:
        label = f'{co2} ppm'
    labels.append(label)
mm = 1/25.4  # mm in inches
fig, ax = plt.subplots(figsize=(180*mm,120*mm))

# Set Y-axis limits
ax.set_ylim(-5, 35)
ax.set_xlim(255,-3.2)

# Add tick marks for the Y-axis
ax.set_yticks(np.arange(0, 35, 5))
ax.set_xticks(np.arange(0, 251, 50))

ax.set_yticks(np.arange(0, 35.5, 1), minor=True)
ax.set_xticks(np.arange(0, 251, 10), minor=True)

# Customize grid appearance
ax.xaxis.remove_overlapping_locs = False
ax.yaxis.remove_overlapping_locs = False

ax.plot(df.index, df['Scotese'], linewidth=1.6, color='purple', linestyle='-', label='Scotese, 2021')
i=0
for i in range(len(co2s)):
    co2 = co2s[i]
    print(co2)
    try:
        ax.scatter(x=df.index,y=df[co2], marker='*', facecolors='lightgrey', edgecolors=None, linewidths=1, s=100, alpha=0.5)
    except:
        continue
    i+=1
for age in modelDict:
    co2 = modelDict[age]
    try:
        ax.scatter(x=age,y=df.loc[age,co2], marker='*', facecolors=colourDict[co2], edgecolors='black', linewidths=1, s=200)
    except:
        continue
    

ax.set_xlabel('Age (Ma)')
ax.set_ylabel('GMST ($^\circ$C)')

# Hide the right and top spines
ax.spines[['right', 'top']].set_visible(False)

ax.legend(markers, labels, loc='best', ncol=2, frameon=False)

ax2 = ax.twinx()
ax2.plot(np.NaN, np.NaN, linewidth=1.6, color='purple', linestyle='-', label='Scotese et al. 2021 Paleotemperatures')
ax2.get_yaxis().set_visible(False)
ax2.spines[['right', 'top']].set_visible(False)

ax2.legend(frameon=False)

plt.savefig(f'gmst_comparison_optimum.png', dpi=300)
# Out:
# 100
# 200
# 280
# 560
# 1120
# 2240
# 4480
# fosterCO2

# %%
markers
# Out:
# [<matplotlib.lines.Line2D at 0x1ac7d75d0>,
#  <matplotlib.lines.Line2D at 0x1adc83710>,
#  <matplotlib.lines.Line2D at 0x1ad5f29d0>,
#  <matplotlib.lines.Line2D at 0x1ad5f1d10>,
#  <matplotlib.lines.Line2D at 0x1ad5f0750>,
#  <matplotlib.lines.Line2D at 0x1ad5f2e50>,
#  <matplotlib.lines.Line2D at 0x1ad5f11d0>,
#  <matplotlib.lines.Line2D at 0x1ad5f1510>]
